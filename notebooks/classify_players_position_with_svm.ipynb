# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("../data/players_preprocessed_and_grouped_positions.csv")
df.columns
# Out:
# Index(['OVERALL_RATING', 'POTENTIAL', 'VALUE', 'WAGE', 'HEIGHT', 'KIT_NUMBER',
#        'WEAK_FOOT', 'SKILL_MOVES', 'RELEASE_CLAUSE', 'CROSSING', 'FINISHING',
#        'HEADING_ACCURACY', 'SHORT_PASSING', 'VOLLEYS', 'DRIBBLING', 'CURVE',
#        'FK_ACCURACY', 'LONG_PASSING', 'BALL_CONTROL', 'ACCELERATION',
#        'SPRINT_SPEED', 'AGILITY', 'REACTIONS', 'BALANCE', 'SHOT_POWER',
#        'JUMPING', 'STAMINA', 'STRENGTH', 'LONG_SHOTS', 'AGGRESSION',
#        'INTERCEPTIONS', 'POSITIONING', 'VISION', 'PENALTIES', 'COMPOSURE',
#        'DEFENSIVE_AWARENESS', 'STANDING_TACKLE', 'SLIDING_TACKLE', 'GK_DIVING',
#        'GK_HANDLING', 'GK_KICKING', 'GK_POSITIONING', 'GK_REFLEXES', 'AGE',
#        'BROAD_POSITION'],
#       dtype='object')

# %%
scaler = MinMaxScaler()
scaler.fit(df.drop(['BROAD_POSITION'], axis=1))
x_scaled = scaler.transform(df.drop(['BROAD_POSITION'], axis=1))
df_scaled = pd.DataFrame(x_scaled, columns=['OVERALL_RATING', 'POTENTIAL', 'VALUE', 'WAGE', 'HEIGHT', 'KIT_NUMBER',
       'WEAK_FOOT', 'SKILL_MOVES', 'RELEASE_CLAUSE', 'CROSSING', 'FINISHING',
       'HEADING_ACCURACY', 'SHORT_PASSING', 'VOLLEYS', 'DRIBBLING', 'CURVE',
       'FK_ACCURACY', 'LONG_PASSING', 'BALL_CONTROL', 'ACCELERATION',
       'SPRINT_SPEED', 'AGILITY', 'REACTIONS', 'BALANCE', 'SHOT_POWER',
       'JUMPING', 'STAMINA', 'STRENGTH', 'LONG_SHOTS', 'AGGRESSION',
       'INTERCEPTIONS', 'POSITIONING', 'VISION', 'PENALTIES', 'COMPOSURE',
       'DEFENSIVE_AWARENESS', 'STANDING_TACKLE', 'SLIDING_TACKLE', 'GK_DIVING',
       'GK_HANDLING', 'GK_KICKING', 'GK_POSITIONING', 'GK_REFLEXES', 'AGE'])

df_scaled.head()
# Out:
#    OVERALL_RATING  POTENTIAL     VALUE      WAGE  HEIGHT  KIT_NUMBER  \
# 0        0.688889   0.750000  0.022051  0.001053    0.28    0.102041
# 1        0.866667   0.840909  0.075385  0.178947    0.60    0.091837
# 2        0.533333   0.704545  0.003692  0.018947    0.48    0.642857
# 3        0.822222   0.863636  0.054359  0.076842    0.74    0.112245
# 4        0.866667   0.886364  0.082051  0.115789    0.44    0.061224
#
#    WEAK_FOOT  SKILL_MOVES  RELEASE_CLAUSE  CROSSING  ...  COMPOSURE  \
# 0       0.75     0.100000        0.000000  0.747126  ...   0.783133
# 1       0.50     0.133333        0.145491  0.804598  ...   0.831325
# 2       0.50     0.066667        0.007615  0.793103  ...   0.698795
# 3       0.50     0.033333        0.111523  0.586207  ...   0.819277
# 4       0.50     0.066667        0.158317  0.862069  ...   0.795181
#
#    DEFENSIVE_AWARENESS  STANDING_TACKLE  SLIDING_TACKLE  GK_DIVING  \
# 0             0.540230         0.470588        0.345238   0.113636
# ...

# %%
x = df_scaled
y = df['BROAD_POSITION']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=101, shuffle=True)

svc = SVC(kernel='poly', C=2.0, random_state = 101)
accuracies = cross_val_score(svc, x_train, y_train, cv=5)
svc.fit(x_train, y_train)

print("Train Score:", np.mean(accuracies))
print("Test Score:", svc.score(x_test, y_test))
# Out:
# Train Score: 0.8770566615490676
# Test Score: 0.875
